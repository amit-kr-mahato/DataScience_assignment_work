# %% [markdown]
# ## Mini Assignment 3

# %%
a=int(input("enter the 1 number"))
b=int(input("enter the 2 number"))
sum=a+b
diff=a-b
pro=a*b
print(sum,diff,pro)
if(a%b==0):
    print("number disible")
else:
    print("not disible")
# Out:
# enter the 1 number 4
# enter the 2 number 4
# 8 0 16
# number disible

# %%
a=int(input("enter the 1 number"))
b=int(input("enter the 2 number"))
print("is both even",a%2==0  and b%2==0)
# Out:
# enter the 1 number 3
# enter the 2 number 4
# is both even False
