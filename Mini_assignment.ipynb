# %% [markdown]
# # mini assignment 1

# %% [markdown]
# print full name

# %%
print("amit kumar mahato")
# Out:
# amit kumar mahato

# %% [markdown]
# QN:2 Favourate quotes

# %%
print("i am mahato")
# Out:
# i am mahato

# %% [markdown]
# QN.3 SENTENCE ON MULTIPLE LINE

# %%
print("i am amit \n mahato \n kumar")
# Out:
# i am amit
#  mahato
#  kumar

# %% [markdown]
# # mini assignment 2

# %%
name="amit kumar mahato"
age=20
country="nepal"
print(name,age,country)
# Out:
# amit kumar mahato 20 nepal

# %%
print(type(name),type(age),type(country))
# Out:
# <class 'str'> <class 'int'> <class 'str'>

# %% [markdown]
# # mini assignment-3
