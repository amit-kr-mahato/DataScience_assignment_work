# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

print("NumPy version:", np.__version__)
print("Pandas version:", pd.__version__)
print("Matplotlib version:", matplotlib.__version__)
# Out:
# NumPy version: 2.3.5
# Pandas version: 2.3.3
# Matplotlib version: 3.10.8

# %%
df = pd.read_csv('iris.csv')
print(type(df))
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
df.columns
# Out:
# Index(['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Name'], dtype='object')

# %%
df.dtypes
# Out:
# SepalLength    float64
# SepalWidth     float64
# PetalLength    float64
# PetalWidth     float64
# Name            object
# dtype: object

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]>

# %%
df.SepalLength.plot.hist()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <Axes: ylabel='Frequency'>

# %%
sepal_length_np = df['SepalLength']
print(type(sepal_length_np))
sepal_length_np
# Out:
# <class 'pandas.core.series.Series'>
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLength, Length: 150, dtype: float64

# %%
sepal_lenght = df['SepalLength']
print(type(sepal_lenght))
sepal_lenght_np = sepal_lenght.to_numpy()
print(type(sepal_lenght_np))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'numpy.ndarray'>

# %%
sepal_length_np.shape
# Out:
# (150,)

# %%
plt.imshow(sepal_length_np.reshape(150, 1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 plt.imshow(sepal_length_np.reshape(150, 1))
#
# NameError: name 'sepal_length_np' is not defined

# %%
plt.imshow(sepal_length_np)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 plt.imshow(sepal_lenght_np)
#
# File D:\data-science\data_env\Lib\site-packages\matplotlib\_api\__init__.py:232, in caching_module_getattr.<locals>.__getattr__(name)
#     230 if name in props:
#     231     return props[name].__get__(instance)
# --> 232 raise AttributeError(
#     233     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'imshow'

# %%
sepal_lenght_np.mean()
# Out:
# np.float64(5.843333333333334)

# %%
sepal_lenght_np
# Out:
# array([5.1, 4.9, 4.7, 4.6, 5. , 5.4, 4.6, 5. , 4.4, 4.9, 5.4, 4.8, 4.8,
#        4.3, 5.8, 5.7, 5.4, 5.1, 5.7, 5.1, 5.4, 5.1, 4.6, 5.1, 4.8, 5. ,
#        5. , 5.2, 5.2, 4.7, 4.8, 5.4, 5.2, 5.5, 4.9, 5. , 5.5, 4.9, 4.4,
#        5.1, 5. , 4.5, 4.4, 5. , 5.1, 4.8, 5.1, 4.6, 5.3, 5. , 7. , 6.4,
#        6.9, 5.5, 6.5, 5.7, 6.3, 4.9, 6.6, 5.2, 5. , 5.9, 6. , 6.1, 5.6,
#        6.7, 5.6, 5.8, 6.2, 5.6, 5.9, 6.1, 6.3, 6.1, 6.4, 6.6, 6.8, 6.7,
#        6. , 5.7, 5.5, 5.5, 5.8, 6. , 5.4, 6. , 6.7, 6.3, 5.6, 5.5, 5.5,
#        6.1, 5.8, 5. , 5.6, 5.7, 5.7, 6.2, 5.1, 5.7, 6.3, 5.8, 7.1, 6.3,
#        6.5, 7.6, 4.9, 7.3, 6.7, 7.2, 6.5, 6.4, 6.8, 5.7, 5.8, 6.4, 6.5,
#        7.7, 7.7, 6. , 6.9, 5.6, 7.7, 6.3, 6.7, 7.2, 6.2, 6.1, 6.4, 7.2,
#        7.4, 7.9, 6.4, 6.3, 6.1, 7.7, 6.3, 6.4, 6. , 6.9, 6.7, 6.9, 5.8,
#        6.8, 6.7, 6.7, 6.3, 6.5, 6.2, 5.9])
